# %%
import anthropic

client = anthropic.Anthropic(api_key='sk-22b986366e084cafae975331ae994e8a',
                                       base_url='http://127.0.0.1:8000')

response = client.beta.messages.create(
    # model="claude-sonnet-4-5-20250929",
    model="global.anthropic.claude-opus-4-5-20251101-v1:0",
    max_tokens=1024,
    betas=["advanced-tool-use-2025-11-20"],
    tools=[
        {
            "name": "get_weather",
            "description": "Get the current weather in a given location",
            "input_schema": {
                "type": "object",
                "properties": {
                    "location": {
                        "type": "string",
                        "description": "The city and state, e.g. San Francisco, CA"
                    },
                    "unit": {
                        "type": "string",
                        "enum": ["celsius", "fahrenheit"],
                        "description": "The unit of temperature"
                    }
                },
                "required": ["location"]
            },
            "input_examples": [
                {
                    "location": "San Francisco, CA",
                    "unit": "fahrenheit"
                },
                {
                    "location": "Tokyo, Japan",
                    "unit": "celsius"
                },
                {
                    "location": "New York, NY"  # 'unit' is optional
                }
            ]
        }
    ],
    messages=[
        {"role": "user", "content": "What's the weather like in San Francisco?"}
    ]
)

# %%
response
# Out:
# BetaMessage(id='msg-9d6879848338454ba82b1fa1136ee826', container=None, content=[BetaToolUseBlock(id='toolu_bdrk_01PB1eoMqvaPjpuodJywSg3o', input={'location': 'San Francisco, CA'}, name='get_weather', type='tool_use', caller=None)], context_management=None, model='global.anthropic.claude-opus-4-5-20251101-v1:0', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=BetaUsage(cache_creation=None, cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=828, output_tokens=56, server_tool_use=None, service_tier=None))

# %%
response = client.beta.messages.create(
    model="claude-opus-4-5-20251101",
    betas=["advanced-tool-use-2025-11-20"],
    max_tokens=2048,
    messages=[
        {
            "role": "user",
            "content": "What is the weather in San Francisco?"
        }
    ],
    tools=[
        {
            "type": "tool_search_tool_regex_20251119",
            "name": "tool_search_tool_regex"
        },
        {
            "name": "get_weather",
            "description": "Get the weather at a specific location",
            "input_schema": {
                "type": "object",
                "properties": {
                    "location": {"type": "string"},
                    "unit": {
                        "type": "string",
                        "enum": ["celsius", "fahrenheit"]
                    }
                },
                "required": ["location"]
            },
            "defer_loading": True
        },
        {
            "name": "search_files",
            "description": "Search through files in the workspace",
            "input_schema": {
                "type": "object",
                "properties": {
                    "query": {"type": "string"},
                    "file_types": {
                        "type": "array",
                        "items": {"type": "string"}
                    }
                },
                "required": ["query"]
            },
            "defer_loading": True
        }
    ]
)

print(response)
# Out:
# BetaMessage(id='msg-4946baddffd74426ab0ddefe84342dcb', container=None, content=[BetaTextBlock(citations=None, text="I'll search for weather-related tools that can help answer your question.", type='text', cache_control=None), BetaTextBlock(citations=None, text='I found a weather tool. Let me get the weather for San Francisco.', type='text', cache_control=None), BetaToolUseBlock(id='toolu_bdrk_011L96zJrQrFR589p5hGs2Hv', input={'location': 'San Francisco'}, name='get_weather', type='tool_use', caller=None)], context_management=None, model='claude-opus-4-5-20251101', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=BetaUsage(cache_creation=None, cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1617, output_tokens=143, server_tool_use=None, service_tier=None))
